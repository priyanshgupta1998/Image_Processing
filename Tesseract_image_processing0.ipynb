# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshgupta1998/Opencv_practice/blob/master/Tesseract_image_processing0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TEXT recognition   (IMAGE PROCESSING)
# In the process of character recognizing we will be unsing python software library 'tesseract'     .

# %% [markdown]
# https://github.com/tesseract-ocr/tesseract/wiki/4.0-with-LSTM#400-alpha-for-windows
#
# ---
#
#
#
# ---
#
# https://medium.com/@bhadreshpsavani/how-to-use-tesseract-library-for-ocr-in-google-colab-notebook-5da5470e4fe0
#
# ---
#
#
#
# ---
#
# https://github.com/labdeeman7/document-ocr/blob/master/classification%20via%20NLP%20and%20information%20extraction.ipynb
#
# ---
#
#
#
# ---

# %%
# !pip install pytesseract
# Out:
# ...
#     100% |████████████████████████████████| 174kB 8.0MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/d5/90/56/ab7b652592da86821293f7cadc1c554aa376a0d57ce414d0a0
# Successfully built pytesseract
# ...

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 6 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# ...

# %%
import pytesseract
import shutil
# %pylab inline
import matplotlib.pyplot as plt
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fe06844e-7f62-485d-a40a-e1cf29ebdf55" name="files[]" multiple disabled />
#      <output id="result-fe06844e-7f62-485d-a40a-e1cf29ebdf55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tesseract0.jpg to tesseract0 (1).jpg
# Saving tesseract1.jpg to tesseract1 (1).jpg
# Saving text-image0.jpg to text-image0 (1).jpg
# Saving text-image1.png to text-image1 (1).png
# Saving text-image2.jpeg to text-image2 (1).jpeg
# Saving text-image3.png to text-image3 (1).png
# Saving text-image4.jpg to text-image4 (1).jpg
# Saving text-image5.png to text-image5 (1).png

# %%
img=imread('tesseract0.jpg')
imgplot = plt.imshow(img)
plt.grid(False)
plt.show()
extractedInformation1 = pytesseract.image_to_string(Image.open('tesseract0.jpg'))
print(extractedInformation1 )
# Out:
# Tesseract Will
# Fail With Noisy
# Backgrounds

# %%
# !ls  # files in current working direcory
# Out:
# sample_data	text-image0.jpg   text-image3.png
# tesseract0.jpg	text-image1.png   text-image4.jpg
# tesseract1.jpg	text-image2.jpeg  text-image5.png

# %%
with open("/home/copy.txt", "w") as file:   # create a file 
    file.write(extractedInformation1)

# %%
img=imread('tesseract1.jpg')
imgplot = plt.imshow(img)
plt.grid(False)
# plt.figure(figsize=(20,10))
plt.show()
extractedInformation2 = pytesseract.image_to_string(Image.open('tesseract1.jpg'))
print(extractedInformation2 )
# Out:
# (COED ei Pa rol ene Beene beale prea Kelilmetlel wore «Me oat
# CooL ge a LR a1}
#
# ecto pm ela MER Pe eae eel a |
#
# eT Card #: 5476767898765432
#
# Se
#
# 5476 7678 98765432)
#
#
#
# ee)
#
# OA pss

# %%
img=imread('text-image0.jpg')
imgplot = plt.imshow(img)
plt.grid(False)
plt.show()
extractedInformation3 = pytesseract.image_to_string(Image.open('text-image0.jpg'))
print(extractedInformation3 )
# Out:
# Since 2008

# %%
img=imread('text-image1.png')
imgplot = plt.imshow(img)
plt.grid(False)
plt.show()
extractedInformation4 = pytesseract.image_to_string(Image.open('text-image1.png'))
print(extractedInformation4)
# Out:
# Don't Do This!
#
# Here | am writing down every word that | am going to
# say aloud when | give the presentation. All the text
# taking up space on the screen is going to make it really
# difficult for people to listen and to read everything at
# ‘once, even though they are the same thing. it'd be
# better if | just went and added a couple key points on
# the slide and elaborate on them by referring to some.
# flash cards or memorizing what I'm going to say.

# %%
img=imread('text-image2.jpeg')
imgplot = plt.imshow(img)
plt.grid(False)
plt.show()
extractedInformation5 = pytesseract.image_to_string(Image.open('text-image2.jpeg'))
print(extractedInformation5)
# Out:
# — Bat fet F2 Gbh puiffe
# elt x Waban Toby Bal pega fod
#
# quires dh Ch Bek
#
# ern in
#
# Tee ni 9 dhe.
#
# vere, fir he flan wif hy Ferre om
# nega ech ake
#
# i Blftyerpe ux cle dol tanke'f ay
#
# pope peomin/ios Hos Yen alarpbaban mitch. ae
#
# punee afrrn deat be
#
# Ee fee ie pr tapi
#
# ‘S. 5. bok fp he Mharriaftay Ar Bipinde
#
# Ubainoring det frig anbagrn yie Aberedfuct,
#
# AvWiboles furiftce thes fe Dorhintatrefe Rat bel
#
# ii 1 Aaah sis Ieltedlbentey,
#
# #

# %%
img=imread('text-image3.png')
imgplot = plt.imshow(img)
plt.grid(False)
plt.show()
extractedInformation5 = pytesseract.image_to_string(Image.open('text-image3.png'))
print(extractedInformation5)
# Out:
# ohm Postion’ GWO lool Sod a
# 2 DICrr aeles though just fir fiSG rein ike stil...
# we day SPE Or ws without’ now say UNO ought - asked general hight
# hand trench know life something ONC Wellirncnns
# -bime Chapter events arcaas, SH poked ™ —e
# “sates ANEW 7 eNabasha cur princessrostov
#
# oat mancounts utero rine ce y began
#
# anobher fell
# smi eg away COME sone love MOSCOW head Old "ri
# last'ONS MENaiways Mary fore wholeeveryehing back litble
#
# roundheard moment felt ol Noris $8 saw officermans going
# dive ay sab made denise
#
# tober horse

# %%
img=imread('text-image4.jpg')
imgplot = plt.imshow(img)
plt.grid(False)
plt.show()
extractedInformation6 = pytesseract.image_to_string(Image.open('text-image4.jpg'))
print(extractedInformation6)

# %%
img=imread('text-image5.png')
imgplot = plt.imshow(img)
plt.grid(False)
plt.show()
extractedInformation7 = pytesseract.image_to_string(Image.open('text-image5.png'))
print(extractedInformation7)
# Out:
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
# ‘A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# ‘A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# ‘A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789
#
# A Quick Brown Fox Jumps Over The Lazy Dog 0123456789

# %% [markdown]
# #Image Resizing     (respective)
# https://pypi.org/project/python-resize-image/

# %%
# !pip install python-resize-image
# Out:
# ...
#     100% |████████████████████████████████| 61kB 5.5MB/s
# ...
#     100% |████████████████████████████████| 2.0MB 11.3MB/s
# ...
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# imgaug 0.2.8 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# google-colab 1.0.0 has requirement requests~=2.18.0, but you'll have requests 2.21.0 which is incompatible.
# fastai 1.0.50.post1 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.8 which is incompatible.
# ...
#   Found existing installation: requests 2.18.4
#     Uninstalling requests-2.18.4:
#       Successfully uninstalled requests-2.18.4
#   Found existing installation: Pillow 4.1.1
#     Uninstalling Pillow-4.1.1:
# ...

# %%
from PIL import Image
from resizeimage import resizeimage
with open('tesseract1.jpg', 'r+b') as f:
    with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [200, 400])
        cover.save('/home/test-image-cover.jpeg', image.format)
        
img=imread('/home/test-image-cover.jpeg')
imgplot = plt.imshow(img)
plt.grid(False)
plt.show()
