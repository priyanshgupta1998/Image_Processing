# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshgupta1998/Image_Processing/blob/master/OCR_PASSPORT/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytesseract
# !sudo apt install tesseract-ocr

# %% [markdown]
# a) prepare an excel  showing what was the text output for each image. We should be able to capture the following fields on the RC:
# - License plate number or Regn number
# - VIN number or Chassis number (typically 17 digit long)
# - Name
# - Engine number
# - Registration date
# - Mfg. date

# %%
import os
import cv2
import pytesseract
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image 
import sys
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = '/content/drive/My Drive/RC'
print(len(os.listdir(path)))   # 46 images we have
# Out:
# 46

# %%
print(os.listdir(path))
# Out:
# ['txt_mudit_b8_1_545.jpg', 'txt_mudit_b8_1_571.jpg', 'txt_mudit_b8_1_808.jpg', 'txt_mudit_b8_1_546.jpg', 'txt_mudit_b8_1_513.jpg', 'txt_mudit_b8_1_554.jpg', 'txt_mudit_b8_1_573.jpg', 'txt_mudit_b8_1_807.jpg', 'txt_mudit_b8_1_574.jpg', 'txt_mudit_b8_1_555.jpg', 'txt_mudit_b8_1_742.jpg', 'txt_mudit_b8_1_741.jpg', 'txt_mudit_b8_1_740.jpg', 'txt_mudit_b8_1_806.jpg', 'txt_mudit_b8_1_854.jpg', 'txt_mudit_b8_1_855.jpg', 'txt_mudit_b8_2_213.jpg', 'txt_mudit_b11_12.jpg', 'txt_mudit_b11_439.jpg', 'txt_mudit_b11_480.jpg', 'txt_mudit_b11_746.jpg', 'txt_mudit_b11_961.jpg', 'txt_mudit_b11_1343.jpg', 'txt_mudit_b11_1330.jpg', 'txt_mudit_b11_1369.jpg', 'txt_mudit_b11_1339.jpg', 'txt_mudit_b11_1332.jpg', 'txt_mudit_b11_1337.jpg', 'txt_mudit_b11_1328.jpg', 'txt_mudit_b11_1363.jpg', 'txt_mudit_b11_1365.jpg', 'txt_mudit_b11_1334.jpg', 'txt_mudit_b11_1364.jpg', 'txt_mudit_b11_1347.jpg', 'txt_mudit_b11_1361.jpg', 'txt_mudit_b11_1354.jpg', 'txt_mudit_b11_1355.jpg', 'txt_mudit_b11_1362.jpg', 'txt_mudit_b11_
# ...

# %%
# img = cv2.imread(path + '/txt_mudit_b8_1_571.jpg')
# text = pytesseract.image_to_data(img)

# %%
plt.figure(figsize=(20,10))
plt.imshow(img)
plt.title('Original Image'),
plt.xticks([]), 
plt.yticks([])
plt.show()
print(text)
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	2048	1536	-1
# 2	1	1	0	0	0	375	0	488	144	-1
# 3	1	1	1	0	0	375	0	488	144	-1
# 4	1	1	1	1	0	375	0	488	144	-1
# 5	1	1	1	1	1	375	0	488	144	95
# 2	1	2	0	0	0	8	0	1993	1211	-1
# 3	1	2	1	0	0	8	0	1993	1211	-1
# 4	1	2	1	1	0	254	0	1468	54	-1
# 5	1	2	1	1	1	254	0	72	35	37	qv
# 5	1	2	1	1	2	331	0	18	4	68	.
# 5	1	2	1	1	3	398	0	67	30	38	Ape?
# 5	1	2	1	1	4	822	9	29	7	25	ae
# 5	1	2	1	1	5	1115	10	38	36	27	NT
# 5	1	2	1	1	6	1210	0	175	27	29	ate
# 5	1	2	1	1	7	1478	0	244	54	45	hae
# 4	1	2	1	2	0	164	0	1620	156	-1
# 5	1	2	1	2	1	164	10	233	69	19	a
# 5	1	2	1	2	2	691	49	275	101	0	insehise~
# 5	1	2	1	2	3	958	9	174	124	17	ee
# 5	1	2	1	2	4	1115	0	368	156	17	revue
# 5	1	2	1	2	5	1474	40	310	92	27	t=
# 4	1	2	1	3	0	322	79	1415	85	-1
# 5	1	2	1	3	1	322	79	57	65	75	qt
# 5	1	2	1	3	2	404	137	59	8	31	a
# 5	1	2	1	3	3	473	114	72	32	28	Aes
# 5	1	2	1	3	4	562	145	3	1	70	|
# 5	1	2	1	3	5	572	81	129	65	50	ERA!
# ...

# %%
# imag = path + '/txt_mudit_b8_1_545.jpg'
# img = cv2.imread(imag,0)

# h = img.shape[0]//3
# w = img.shape[1]
# crop_img = img[img.shape[0]//4:h-40, w-200:w-20]
# edges = cv2.Canny(img,100,200)

# result = pytesseract.image_to_data(edges, lang='eng', nice=0, output_type=pytesseract.Output.DICT)

# print(set(result['text']))
# plt.figure(figsize=(20,10))
# plt.subplot(121),
# plt.imshow(img,cmap = 'gray')
# plt.title('Original Image'),
# plt.xticks([]), 
# plt.yticks([])
# plt.subplot(122),
# plt.imshow(edges,cmap = 'gray')
# plt.title('Edge Image'), 
# plt.xticks([]), 
# plt.yticks([])
# plt.show()
