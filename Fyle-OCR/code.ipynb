# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshgupta1998/Image_Processing/blob/master/Fyle-OCR/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://stackoverflow.com/questions/54115780/highlighting-specific-text-in-an-image-using-python
#
#
# https://www.danvk.org/2015/01/07/finding-blocks-of-text-in-an-image-using-python-opencv-and-numpy.html

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
path = '/content/drive/My Drive/Receipts/'
fold = os.listdir(path)
print(len(fold))
# Out:
# 595

# %%
# !pip install pytesseract
# !sudo apt install tesseract-ocr

# %%
# import pytesseract
# import shutil
# %pylab inline
# import matplotlib.pyplot as plt
# import os
# import random


# try:
#     from PIL import Image
# except ImportError:
#     import Image
# imag = path  +fold[5]
# img=imread(imag)
# imgplot = plt.imshow(img)
# plt.grid(False)
# # plt.figure(figsize=(20,10))
# plt.show()
# extractedInformation2 = pytesseract.image_to_string(Image.open(imag))
# print(extractedInformation2 )

# %%
# import cv2
# import pytesseract
# import matplotlib.pyplot as plt

# filename = path  +fold[96]

# # read the image and get the dimensions
# img = cv2.imread(filename)


# h, w, _ = img.shape # assumes color image

# # run tesseract, returning the bounding boxes
# boxes = pytesseract.image_to_boxes(img)
# print(pytesseract.image_to_string(img)) #print identified text

# # draw the bounding boxes on the image
# for b in boxes.splitlines():
#     b = b.split()
#     cv2.rectangle(img, ((int(b[1]), h - int(b[2]))), ((int(b[3]), h - int(b[4]))), (0, 255, 0), 2)

# plt.imshow(img)

# %%
# import cv2
# import numpy as np
# from matplotlib import pyplot as plt
# imag = path  +fold[96]
# img = cv2.imread(imag)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# edges = cv2.Canny(img,100,200)
# plt.imshow(edges)

# %%
# Improting Image class from PIL module  
from PIL import Image  
imag = path  +fold[72]
# Opens a image in RGB mode  
im1 = Image.open(imag)  
# print(im) 
newsize = (800,800) 
im1 = im1.resize(newsize, Image.ANTIALIAS)
plt.figure(figsize=(20,10))
plt.imshow(im1)
extractedInformation2 = pytesseract.image_to_string(im1)
print(extractedInformation2)
text = extractedInformation2

# %%
# Improting Image class from PIL module  
from PIL import Image  
imag = path  +fold[71]
# Opens a image in RGB mode  
im1 = Image.open(imag)  
# print(im) 
newsize = (1000 ,1200) 
im1 = im1.resize(newsize, Image.ANTIALIAS)
plt.figure(figsize=(20,10))
plt.imshow(im1)
extractedInformation2 = pytesseract.image_to_string(im1)
print(extractedInformation2)
text = extractedInformation2
# 96,80,79,94,72, , 91 , 89 , 83 , 82

# %%
import cv2
import pytesseract
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image 
import sys
import numpy as np

imag = path  +fold[71]
img = cv2.imread(imag,0)
# img = cv2.resize(img, (800,800), interpolation = cv2.INTER_AREA)
edges = cv2.Canny(img,100,200)
result = pytesseract.image_to_data(img, lang='eng', nice=0, output_type=pytesseract.Output.DICT)

print(set(result['text']))
plt.subplot(121),
plt.imshow(img,cmap = 'gray')
plt.title('Original Image'),
plt.xticks([]), 
plt.yticks([])
plt.subplot(122),
plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), 
plt.xticks([]), 
plt.yticks([])
plt.show()

# %%
# Out:
# 1

# %% [markdown]
# #rough part

# %%
import pytesseract
import cv2

good = []
for j in range(100):
  imag = path  +fold[j]
  app =[]
  liss = []
  img = cv2.imread(imag)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  result = pytesseract.image_to_data(img, lang='eng', nice=0, output_type=pytesseract.Output.DICT)
  for i in list(result.keys()):
    app+=result[i]
  for i in set(app):
    if(len(str(i))>5):
      liss.append(i)
  good.append(liss)

# %%
good[91]
# Out:
# ['Follow',
#  'Twitter',
#  'FREEBIRO',
#  'LONESTAR',
#  'Facebook',
#  '@gourdoughspud',
#  '09:38PM',
#  'greatest',
#  'specials!',
#  'van2t‘17',
#  'ORIGINAL',
#  'Jatest']

# %%
# Improting Image class from PIL module  
from PIL import Image  
timelis = ['\d{2}-\d{2}-\d{2}','(\d+/\d+/\d+)' , '(\w+/\d+/\d+)' ,
           '\d{2}\-\w{3}\-\d{4}',
           "^([1-9] |1[0-9]| 2[0-9]|3[0-1])(.|-)([1-9] |1[0-2])(.|-|)20[0-9][0-9]$",
        '[0-9]{4}-[0-9]{2}-[0-9]{2} [0-9]{2}'  ]   


for i in timelis:
  p = re.compile(i) 
  res = p.findall('be/0/19')
  print(i , res)
# Out:
# \d{2}-\d{2}-\d{2} []
# (\d+/\d+/\d+) []
# (\w+/\d+/\d+) ['be/0/19']
# \d{2}\-\w{3}\-\d{4} []
# ^([1-9] |1[0-9]| 2[0-9]|3[0-1])(.|-)([1-9] |1[0-2])(.|-|)20[0-9][0-9]$ []
# [0-9]{4}-[0-9]{2}-[0-9]{2} [0-9]{2} []

# %%
import datetime
from datetime import date
import re
liss = ['\d{2}-\d{2}-\d{2}' , '\d{2}-\d{2}-\d{2}','(\d+/\d+/\d+)' , "^([1-9] |1[0-9]| 2[0-9]|3[0-1])(.|-)([1-9] |1[0-2])(.|-|)20[0-9][0-9]$",
        '[0-9]{4}-[0-9]{2}-[0-9]{2} [0-9]{2}' ,'\d+\-\w+\-\d+','\w+\-\d+\-\d+' , '\d+\-\d+\-\w+' ]
match = re.search(liss[0],text)

print(match.group())
# try:
#   date = datetime.datetime.strptime(match.group(), '%Y-%m-%d').date()
# except:
#   print('?')

# %%
# Improting Image class from PIL module  
from PIL import Image  
liss = ['\d{2}-\d{2}-\d{2}' ,'(\d+/\d+/\d+)' , "^([1-9] |1[0-9]| 2[0-9]|3[0-1])(.|-)([1-9] |1[0-2])(.|-|)20[0-9][0-9]$",
        '[0-9]{4}-[0-9]{2}-[0-9]{2} [0-9]{2}'  ,'\d{2}\-\w{3}\-\d{4}' , ]   
for j in range(2,4):
  imag = path  +fold[j]
  im1 = Image.open(imag)  
  newsize = (600,600) 
  im1 = im1.resize(newsize, Image.ANTIALIAS) 
  extractedInformation2 = pytesseract.image_to_string(im1)
  text = extractedInformation2
  for i in liss:
    p = re.compile(i) 
    res = p.findall(text)
    if(len(res)>0):
      print(j , res)
  print('-------')

# %%
h = im1.height//3
w = im1.width 
im1 = im1.crop((0,0,w,h))

# %%
import cv2
import pytesseract
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image 
import sys
import numpy as np

imag = path  +fold[71]
img = cv2.imread(imag,0)

h = img.shape[0]//3
w = img.shape[1]
crop_img = img[img.shape[0]//4:h-40, w-200:w-20]
# img = cv2.resize(img, (800,800), interpolation = cv2.INTER_AREA)
edges = cv2.Canny(crop_img,100,200)

result = pytesseract.image_to_data(edges, lang='eng', nice=0, output_type=pytesseract.Output.DICT)

print(set(result['text']))
plt.figure(figsize=(20,10))
plt.subplot(121),
plt.imshow(crop_img,cmap = 'gray')
plt.title('Original Image'),
plt.xticks([]), 
plt.yticks([])
plt.subplot(122),
plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), 
plt.xticks([]), 
plt.yticks([])
plt.show()
# Out:
# {''}
